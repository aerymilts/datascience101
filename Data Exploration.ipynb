# %%
# This is a beginner's guide to using the Pandas package
# Author: Ved Prakash

# %%
# We need to import the relevant Python libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# For nicer plots!!
pd.set_option('display.mpl_style', 'default') 
plt.rcParams['figure.figsize'] = (17, 4)
plt.rcParams['font.family'] = 'sans-serif'
# Out:
# C:\Users\User\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Basic example of a Python code
def print_even_nos(x,y):
    # prints all the even numbers between x and y (both inclusive)
    if x %2 ==0:
        start =x
        
    else :
        start =x+1
    l = range(start,y+1,2)
    
    return l

# %%
l = print_even_nos(2,13)
type(l)
print l
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
# Analysing a Time Series data
# bikes_df = pd.read_csv("./data/bikes.csv", sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date')
bikes_df = pd.read_csv("./data/bikes.csv", sep=';', parse_dates=True, dayfirst=True, index_col='Date')

len(bikes_df)
# Out:
# 310

# %%
# Examing the first few rows of the data
bikes_df[:10]
# Out:
#             Admiralty  Ang Mo kio  Bedok  Bukit Batok  Changi Point  \
# Date
# 2012-01-01         35         NaN      0           38            51
# 2012-01-02         83         NaN      1           68           153
# 2012-01-03        135         NaN      2          104           248
# 2012-01-04        144         NaN      1          116           318
# 2012-01-05        197         NaN      2          124           330
# 2012-01-06        146         NaN      0           98           244
# 2012-01-07         98         NaN      2           80           108
# 2012-01-08         95         NaN      1           62            98
# 2012-01-09        244         NaN      2          165           432
# 2012-01-10        397         NaN      3          238           563
#
#             Bukit Panjang  Jurong West  Kallang  Tampines
# Date
# 2012-01-01             26           10       16       NaN
# 2012-01-02             53            6       43       NaN
# ...

# %%
# Count the number of null values for certain columns
ang_s = bikes_df['Ang Mo kio']
print type(ang_s)



print bikes_df['Ang Mo kio'].isnull().values.sum()
print bikes_df['Bukit Batok'].isnull().values.sum()
# Out:
# <class 'pandas.core.series.Series'>
# 310
# 0

# %%
bikes_df['Changi Point'].plot()

# %% [raw]
# Observe one column of the data

# %%
bikes_df['Changi Point'][5:10]
# Out:
# Date
# 2012-01-06    244
# 2012-01-07    108
# 2012-01-08     98
# 2012-01-09    432
# 2012-01-10    563
# Name: Changi Point, dtype: int64

# %% [raw]
# Observe multiple columns

# %%
bikes_df[['Changi Point', 'Bedok']][:10]
# Out:
#             Changi Point  Bedok
# Date
# 2012-01-01            51      0
# 2012-01-02           153      1
# 2012-01-03           248      2
# 2012-01-04           318      1
# 2012-01-05           330      2
# 2012-01-06           244      0
# 2012-01-07           108      2
# 2012-01-08            98      1
# 2012-01-09           432      2
# 2012-01-10           563      3

# %%
# Selcting with more complex criteria

bikes_df[(bikes_df['Bedok'] > 1000) & (bikes_df['Changi Point'] <5000)][:10]
# Out:
#             Admiralty  Ang Mo kio  Bedok  Bukit Batok  Changi Point  \
# Date
# 2012-03-19       1821         NaN   1024         1278          2581
# 2012-03-20       2481         NaN   1261         1709          3130
# 2012-03-21       2829         NaN   1558         1893          3510
# 2012-03-22       2195         NaN   1030         1640          2654
# 2012-03-23       2115         NaN   1143         1512          2955
# 2012-04-03       2416         NaN   1078         1791          3556
# 2012-04-05       2424         NaN   1036         1823          3273
# 2012-04-11       2328         NaN   1049         1765          3122
# 2012-04-12       3064         NaN   1483         2306          4076
# 2012-04-13       3341         NaN   1505         2565          4465
#
#             Bukit Panjang  Jurong West  Kallang  Tampines
# Date
# 2012-03-19           1609          506     2058       NaN
# 2012-03-20           1955          762     2609       NaN
# ...

# %%
bikes_df[(bikes_df['Bedok'] > 1000) & ((bikes_df['Changi Point'] >3000) & (bikes_df['Changi Point'] <5000))][:10]
# Out:
#             Admiralty  Ang Mo kio  Bedok  Bukit Batok  Changi Point  \
# Date
# 2012-03-20       2481         NaN   1261         1709          3130
# 2012-03-21       2829         NaN   1558         1893          3510
# 2012-04-03       2416         NaN   1078         1791          3556
# 2012-04-05       2424         NaN   1036         1823          3273
# 2012-04-11       2328         NaN   1049         1765          3122
# 2012-04-12       3064         NaN   1483         2306          4076
# 2012-04-13       3341         NaN   1505         2565          4465
# 2012-04-16       3643         NaN   1841         2723          4830
# 2012-04-17       3539         NaN   1616         2636          4592
# 2012-04-18       3570         NaN   1751         2759          4655
#
#             Bukit Panjang  Jurong West  Kallang  Tampines
# Date
# 2012-03-20           1955          762     2609       NaN
# 2012-03-21           2225          993     2846       NaN
# ...

# %%
dummy = bikes_df[(bikes_df['Bedok'] > 1000) & ((bikes_df['Changi Point'] >3000) & (bikes_df['Changi Point'] <5000))]

# Only interested in the dates between 15th March -10th April 2012

print type(dummy.index)

print dummy[(dummy.index>'2012-03-15') & (dummy.index < '2012-04-10')]

# Only print out the columns for Bedok and Changi Point
dummy[(dummy.index>'2012-03-15') & (dummy.index < '2012-04-10')][['Bedok', 'Changi Point']]
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
#             Admiralty  Ang Mo kio  Bedok  Bukit Batok  Changi Point  \
# Date
# 2012-03-20       2481         NaN   1261         1709          3130
# 2012-03-21       2829         NaN   1558         1893          3510
# 2012-04-03       2416         NaN   1078         1791          3556
# 2012-04-05       2424         NaN   1036         1823          3273
#
#             Bukit Panjang  Jurong West  Kallang  Tampines
# Date
# 2012-03-20           1955          762     2609       NaN
# 2012-03-21           2225          993     2846       NaN
# 2012-04-03           1880          513     2450       NaN
# 2012-04-05           1699          355     2463       NaN
#             Bedok  Changi Point
# Date
# 2012-03-20   1261          3130
# 2012-03-21   1558          3510
# 2012-04-03   1078          3556
# 2012-04-05   1036          3273

# %%
bikes_bedok= bikes_df[['Bedok']]
bikes_bedok['month'] = bikes_bedok.index.month

bikes_bedok[:10]
# Out:
# C:\Users\User\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#             Bedok  month
# Date
# 2012-01-01      0      1
# 2012-01-02      1      1
# 2012-01-03      2      1
# 2012-01-04      1      1
# 2012-01-05      2      1
# 2012-01-06      0      1
# 2012-01-07      2      1
# 2012-01-08      1      1
# 2012-01-09      2      1
# 2012-01-10      3      1

# %%
bikes_changi= bikes_df[['Changi Point']]
bikes_changi['weekday'] = bikes_changi.index.weekday


# relabel the index of weekdays to Mon, Tue etc
days = {0:'Mon',1:'Tues',2:'Weds',3:'Thurs',4:'Fri',5:'Sat',6:'Sun'}

bikes_changi['weekday']  = bikes_changi['weekday'].apply(lambda x : days[x])

bikes_changi[:10]
# Out:
# C:\Users\User\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\User\Anaconda\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             Changi Point weekday
# Date
# 2012-01-01            51     Sun
# 2012-01-02           153     Mon
# 2012-01-03           248    Tues
# 2012-01-04           318    Weds
# 2012-01-05           330   Thurs
# 2012-01-06           244     Fri
# ...

# %%
# Distribution by weekday
changi_weekday = bikes_changi.groupby('weekday').sum()

print changi_weekday
# Out:
#          Changi Point
# weekday
# Fri            172390
# Mon            163767
# Sat            105060
# Sun             98308
# Thurs          196715
# Tues           165880
# Weds           186061

# %% [raw]
# Plot a histogram for Changi by weekdays

# %%
changi_weekday.plot(kind='bar')

# %% [markdown]
# # Data Cleaning

# %%
df_311= pd.read_csv('./data/311-service-requests.csv', sep=',')
print len(df_311)
# Out:
# 111069
# C:\Users\User\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df_311[:10]

df_311['Incident Zip'].isnull().sum()
# Out:
# 12262

# %%
# Examine the NAN fields in incident Zip
df_311[df_311['Incident Zip'].isnull()][:10]
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 18     26590389  10/31/2013 12:51:00 AM                     NaN    DOT
# 26     26590509  10/31/2013 12:33:00 AM                     NaN    DOT
# 54     26591287  10/31/2013 12:01:45 AM  10/31/2013 12:02:37 AM    HRA
# 86     26589255  10/30/2013 11:42:00 PM  10/31/2013 12:25:00 AM    DOT
# 188    26590911  10/30/2013 10:32:15 PM                     NaN    DOF
# 200    26591148  10/30/2013 10:27:00 PM  10/31/2013 12:25:00 AM    DOT
# 214    26589319  10/30/2013 10:18:19 PM  10/30/2013 10:18:39 PM    HRA
# 239    26590678  10/30/2013 10:01:12 PM                     NaN    DOF
# 246    26590045  10/30/2013 09:49:00 PM                     NaN    DOF
# 271    26590226  10/30/2013 09:35:59 PM                     NaN  CHALL
#
#                       Agency Name            Complaint Type  \
# 18   Department of Transportation    Street Light Condition
# 26   Department of Transportation    Street Light Condition
# ...

# %%
df_311['Incident Zip'].unique()
# Out:
# array([11432.0, 11378.0, 10032.0, 10023.0, 10027.0, 11372.0, 11419.0,
#        11417.0, 10011.0, 11225.0, 11218.0, 10003.0, 10029.0, 10466.0,
#        11219.0, 10025.0, 10310.0, 11236.0, nan, 10033.0, 11216.0, 10016.0,
#        10305.0, 10312.0, 10026.0, 10309.0, 10036.0, 11433.0, 11235.0,
#        11213.0, 11379.0, 11101.0, 10014.0, 11231.0, 11234.0, 10457.0,
#        10459.0, 10465.0, 11207.0, 10002.0, 10034.0, 11233.0, 10453.0,
#        10456.0, 10469.0, 11374.0, 11221.0, 11421.0, 11215.0, 10007.0,
#        10019.0, 11205.0, 11418.0, 11369.0, 11249.0, 10005.0, 10009.0,
#        11211.0, 11412.0, 10458.0, 11229.0, 10065.0, 10030.0, 11222.0,
#        10024.0, 10013.0, 11420.0, 11365.0, 10012.0, 11214.0, 11212.0,
#        10022.0, 11232.0, 11040.0, 11226.0, 10281.0, 11102.0, 11208.0,
#        10001.0, 10472.0, 11414.0, 11223.0, 10040.0, 11220.0, 11373.0,
#        11203.0, 11691.0, 11356.0, 10017.0, 10452.0, 10280.0, 11217.0,
# ...

# %% [markdown]
# Some observations for the column

# %%
import re
pattern = re.compile(r"\D")
df_311[df_311['Incident Zip'].str.contains(pattern).fillna(False)]
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 29136    26550551  10/24/2013 06:16:34 PM                     NaN    DCA
# 30939    26548831  10/24/2013 09:35:10 AM                     NaN    DCA
# 43290    26532099  10/22/2013 11:55:50 AM                     NaN    TLC
# 70539    26488417  10/15/2013 03:40:33 PM                     NaN    TLC
# 85821    26468296  10/10/2013 12:36:43 PM  10/26/2013 01:07:07 AM    DCA
# 89304    26461137  10/09/2013 05:23:46 PM  10/25/2013 01:06:41 AM    DCA
#
#                           Agency Name              Complaint Type  \
# 29136  Department of Consumer Affairs          Consumer Complaint
# 30939  Department of Consumer Affairs          Consumer Complaint
# 43290   Taxi and Limousine Commission  For Hire Vehicle Complaint
# 70539   Taxi and Limousine Commission              Taxi Complaint
# 85821  Department of Consumer Affairs          Consumer Complaint
# ...

# %% [markdown]
# Homework: Clean up the Incident-zip column so that they only contain digits. How can we infer if the incident-zip are correct?
